# %% [markdown]
# # Creating indices for IIRC

# %%
import json

test_set = json.load(open('data/iirc_test.json','r'))
context_articles = json.load(open("data/context_articles.json",'r'))

# %%
from bs4 import BeautifulSoup


documents = []
all_titles = []

for item in test_set:
    if item['title'].lower() not in all_titles:
        documents.append({
                "title": item['title'],
                "content": item["text"]
            }
        )
        all_titles.append(item['title'].lower())
    for link in item["links"]:
        if link['target'].lower() in context_articles and link['target'].lower() not in all_titles:
            documents.append({
                "title": link['target'],
                "content": context_articles[link['target'].lower()]
            })
            all_titles.append(link['target'].lower())
        else:
            print(link['target'].lower())
# Out:
# 9th paratroopers assault regiment "col moschin"
# goldfinger (film)
# list of international cricket council members
# icc americas championship
# the rev
# avenged sevenfold
# fox footy
# herald sun
# fox footy
# herald sun
# united states
# judeo-iraqi arabic
# maya civilization
# black watch
# suicidal tendencies
# western hockey league
# national hockey league
# home run
# minor league baseball
# colonel
# colonel
# massachusetts institute of technology
# israel
# harvard business review
# american football
# college football
# united states
# billboard 200
# romeo discography
# billboard 200
# master p
# hip hop history
# billboard 200
# louisiana
# arizona
# state farm stadium
# louisiana
# united states
# gulf of mexico
# saffir–simpson scale
# forgotten realms
# list of dungeons & dragons rulebooks
# mexico
# napoleon iii
# american football
# national football league
# mexico
# lucha libre
# protagonist
# double dragon
# world war ii
# banff, alberta
# american football
# quarterback
# college football
# 2009 nfl draft
# new york city
# los angeles
# metal massacre
# metal massacre
# hull city a.f.c.
# port phillip district
# slant magazine
# everton f.c.
# everton f.c.
# florence
# soviet union
# world hockey association
# fa cup
# mets de guaynabo (basketball)
# mets de guaynabo (basketball)
# mario morales coliseum
# mario morales coliseum
# guaynabo fluminense fc
# puerto rico soccer league
# guaynabo fluminense fc
# recording industry association of america
# united kingdom
# fc kariya
# south australia
# adelaide
# ice hockey
# canada
# university of toronto
# the pittsburgh press
# royal navy
# chicago
# rock and roll
# spanish civil war
# boston brawlers
# luanda
# sony
# florida
# florida public service commission
# world series
# national league
# mediterranean fleet
# member of parliament
# bruce lee
# shandong
# continental divide of the americas
# shankh monastery
# the emperor jones
# france
# napoleon
# belgium
# detroit pistons
# english channel
# royal australian navy
# republic of china navy
# order of the red banner
# harper's magazine
# morris museum of art
# midwestern united states
# french union
# sex organ
# dismissal of james comey
# national basketball association
# omaha, nebraska
# birmingham city f.c.
# australia
# cape town
# jerusalem
# football league second division
# q (magazine)
# r.e.m.
# new york city
# canada
# southampton
# the bahamas
# quebec
# ministry of commerce and industry (india)
# licence raj
# river thames
# fishman (wrestler)
# athens
# professional wrestling
# professional wrestling match types
# rob van dam
# professional wrestling authority figures
# bury f.c.
# liverpool f.c.
# minor counties of english and welsh cricket
# first-class cricket
# world war ii
# democratic party (united states)
# pop music
# slant magazine
# g (musical note)
# europe
# world war i
# detroit
# world war ii
# english channel
# river thames
# canada
# provinces and territories of canada
# germany
# bbc
# member of parliament
# karl marx
# fascism
# bbc
# dallas cowboys
# national football league
# jason witten
# italy national football team
# usl championship
# a-league (1995–2004)
# national professional soccer league (1984–2001)
# harvard university
# professor
# michigan state university
# algeria
# world war i
# television pilot
# national league
# 2004 national league division series
# 2004 national league championship series
# world series
# world war ii
# united states air force
# cold war
# gulf war
# soviet union
# lockheed c-141 starlifter
# lockheed c-130 hercules
# dover air force base
# gymnasium (school)
# dubrovnik
# harvard university
# bonwit teller
# europe
# siberia
# canada
# people of the wolf
# american broadcasting company
# lieutenant
# communist party of china
# soviet union
# moscow
# type ix submarine
# fifa world cup
# 1994 fifa world cup
# cleveland international records
# grammy award
# grammy award
# cleveland international records
# joey miskulin
# grammy award
# paul oakenfold
# r.e.m.
# sputnikmusic
# compilation album
# extended play
# single (music)
# british phonographic industry
# billboard 200
# united states
# variety (magazine)
# canada
# pulp fiction
# american hockey league
# goals against average
# lawyer
# english language
# napoleon
# battle of kulm
# extended play
# emi
# billboard hot 100
# overhead camshaft
# eugene o'neill
# philadelphia
# new york city
# dean (education)
# chicago
# egypt
# atlantic ocean
# indian ocean
# american football
# balkans
# jews
# world war ii
# first-class cricket
# batting average (cricket)
# bowling average
# west germany
# catholic church
# kolkata
# soap opera
# united states
# the a-team
# brush with danger
# howard university
# japan
# the new york times
# obie award
# liverpool
# philadelphia
# english language
# democratic party (united states)
# republican party (united states)
# methodism
# glossary of professional wrestling terms
# sacramento, california
# wwe
# wwe tough enough
# professional wrestling match types
# scotland
# jerusalem
# sea of galilee
# stanley cup
# boston bruins
# boston bruins
# buffalo sabres
# national hockey league
# american hockey league
# international hockey league (1945–2001)
# world hockey association
# wwe nxt
# wwe raw
# wwe intercontinental championship
# 2014 fig rhythmic gymnastics world cup series
# 2014 fig rhythmic gymnastics world cup series
# rhythmic gymnastics grand prix
# melbourne
# lyon
# venice
# rome
# naples
# florence
# tampa bay rowdies (1975–93)
# united states
# united states army
# united states navy
# spanish navy
# soviet union
# egypt
# master of arts
# queen's university belfast
# world war ii
# iași
# alexandru ioan cuza university
# university of peshawar
# bachelor of laws
# bbc
# wii
# los angeles dodgers
# pac-12 conference
# billboard 200
# billboard (magazine)
# billboard hot 100
# australia
# national basketball association
# dallas mavericks
# indiana pacers
# cleveland cavaliers
# world war ii
# malta
# port said
# alexandria
# tobruk
# washington, d.c.
# national league (division)
# efl league two
# northampton town f.c.
# premier league
# birmingham city f.c.
# west bromwich albion f.c.
# fa cup
# sheffield wednesday f.c.
# wembley stadium
# everton f.c.
# disc jockey
# michael jackson
# fjord horse
# sunniva
# germany
# mississippi river
# st. louis
# earned run average
# innings pitched
# batting average (baseball)
# perth
# saint patrick's day
# university of michigan
# associated press
# nebraska cornhuskers football
# liverpool f.c.
# thessaloniki
# tbilisi
# iraq
# itv granada
# united states
# sydney
# first-class cricket
# world war i
# efl league two
# scunthorpe united f.c.
# national cartoonists society
# peabody award
# emmy award
# time (magazine)
# belgian first division a
# list of legends of tomorrow characters
# list of legends of tomorrow characters
# list of legends of tomorrow characters
# list of legends of tomorrow characters
# list of legends of tomorrow characters
# list of legends of tomorrow characters
# list of legends of tomorrow characters
# list of legends of tomorrow characters
# menhir
# malta
# nascar cup series
# nascar gander rv & outdoors truck series
# nascar
# seating capacity
# world war ii
# united states
# showtime (tv network)
# paris
# rome
# montreal wanderers
# world war i
# milwaukee brewers
# free agent
# minor league baseball
# minor league baseball
# university of cambridge
# world war ii
# dna
# hydrogen bond
# dna
# university of cambridge
# athens
# ottoman empire
# united states
# french indochina
# french protectorate of laos
# st aldate's church
# christ church, oxford
# bachelor of arts
# master of arts
# bachelor of divinity
# doctor of divinity
# university of oxford
# war of the first coalition
# french first republic
# war of the first coalition
# belgium
# france
# pink floyd
# heavy metal music
# rush (band)
# punk rock
# bad brains
# biology
# chemistry
# ukraine
# tirana
# fc metalurh donetsk
# lazar popović
# independent politician
# poland
# poland
# france
# world war i
# paris
# association football
# birmingham city f.c.
# cardiff city f.c.
# huddersfield town a.f.c.
# second vatican council
# latin
# jesus
# major (united kingdom)
# south africa
# world war i
# order of the british empire
# marylebone cricket club
# aide-de-camp
# napoleon
# french invasion of russia
# vistula
# battle of leipzig
# hyderabad state
# jawaharlal nehru
# red army
# soviet union
# treaty of versailles
# french revolutionary wars
# mediterranean sea
# royal shakespeare company
# miley stewart
# hannah montana (soundtrack)
# pop rock
# england national football team
# efl cup
# leeds united f.c.
# caribbean
# lisbon
# spain
# france
# stockholm
# romanian bridgehead
# hotchkiss h35
# nbc
# history of the united states
# university of oxford
# emeritus
# university of california, los angeles
# fc barcelona
# the daily telegraph
# the beatles
# elton john
# nme
# dj shadow
# radiohead
# r.e.m.
# allmusic
# hi-fi news & record review
# stylus magazine
# world war ii
# india
# tibet
# hanoi
# hanoi
# shandong
# henan
# oxford
# uk singles chart

# %%
from tqdm import tqdm
import spacy

nlp = spacy.blank("en")
nlp.add_pipe(nlp.create_pipe("sentencizer"))

stride = 2
max_length = 3

def window(documents, stride=2, max_length=3):
    treated_documents = []

    for j,document in enumerate(tqdm(documents)):
        doc_text = document['content']
        doc = nlp(doc_text[:10000])
        sentences = [sent.string.strip() for sent in doc.sents]
        for i in range(0, len(sentences), stride):
            segment = ' '.join(sentences[i:i + max_length])
            treated_documents.append({
                "title": document['title'],
                "contents": document['title']+". "+segment,
                "segment": segment
            })
            if i + max_length >= len(sentences):
                break
    return treated_documents

treated_documents = window(documents)
# Out:
# 100%|██████████| 7028/7028 [01:53<00:00, 61.70it/s]

# %%
# !mkdir data/iirc_indices

# %%
f = open("data/iirc_indices/contents.jsonl",'w')

for i, doc in enumerate(treated_documents):
    doc['id'] = i
    if doc['segment'] != "":
        f.write(json.dumps(doc)+"\n")

# %%
# !python3 -m pyserini.index -collection JsonCollection -generator DefaultLuceneDocumentGenerator -threads 1 -input data/iirc_indices -index data/iirc_index -storeRaw
# Out:
# WARNING: sun.reflect.Reflection.getCallerClass is not supported. This will impact performance.
# 2022-10-19 19:49:52,586 INFO  [main] index.IndexCollection (IndexCollection.java:650) - Setting log level to INFO
# 2022-10-19 19:49:52,589 INFO  [main] index.IndexCollection (IndexCollection.java:653) - Starting indexer...
# 2022-10-19 19:49:52,589 INFO  [main] index.IndexCollection (IndexCollection.java:654) - ============ Loading Parameters ============
# 2022-10-19 19:49:52,589 INFO  [main] index.IndexCollection (IndexCollection.java:655) - DocumentCollection path: data/iirc_indices
# 2022-10-19 19:49:52,590 INFO  [main] index.IndexCollection (IndexCollection.java:656) - CollectionClass: JsonCollection
# 2022-10-19 19:49:52,590 INFO  [main] index.IndexCollection (IndexCollection.java:657) - Generator: DefaultLuceneDocumentGenerator
# 2022-10-19 19:49:52,590 INFO  [main] index.IndexCollection (IndexCollection.java:658) - Threads: 1
# 2022-10-19 19:49:52,591 INFO  [main] index.IndexCollection (IndexCollection.java:659) - Stemmer: porter
# 2022-10-19 19:49:52,591 INFO  [main] index.IndexCollection (IndexCollection.java:660) - Keep stopwords? false
# 2022-10-19 19:49:52,591 INFO  [main] index.IndexCollection (IndexCollection.java:661) - Stopwords:  null
# 2022-10-19 19:49:52,592 INFO  [main] index.IndexCollection (IndexCollection.java:662) - Store positions? false
# 2022-10-19 19:49:52,592 INFO  [main] index.IndexCollection (IndexCollection.java:663) - Store docvectors? false
# 2022-10-19 19:49:52,592 INFO  [main] index.IndexCollection (IndexCollection.java:664) - Store document "contents" field? false
# 2022-10-19 19:49:52,593 INFO  [main] index.IndexCollection (IndexCollection.java:665) - Store document "raw" field? true
# 2022-10-19 19:49:52,593 INFO  [main] index.IndexCollection (IndexCollection.java:666) - Optimize (merge segments)? false
# 2022-10-19 19:49:52,593 INFO  [main] index.IndexCollection (IndexCollection.java:667) - Whitelist: null
# 2022-10-19 19:49:52,594 INFO  [main] index.IndexCollection (IndexCollection.java:687) - Directly building Lucene indexes...
# 2022-10-19 19:49:52,594 INFO  [main] index.IndexCollection (IndexCollection.java:688) - Index path: data/iirc_index
# 2022-10-19 19:49:52,596 INFO  [main] index.IndexCollection (IndexCollection.java:737) - ============ Indexing Collection ============
# 2022-10-19 19:49:52,709 INFO  [main] index.IndexCollection (IndexCollection.java:798) - Thread pool with 1 threads initialized.
# 2022-10-19 19:49:52,710 INFO  [main] index.IndexCollection (IndexCollection.java:800) - Initializing collection in data/iirc_indices
# 2022-10-19 19:49:52,714 INFO  [main] index.IndexCollection (IndexCollection.java:803) - 1 file found
# 2022-10-19 19:49:52,714 INFO  [main] index.IndexCollection (IndexCollection.java:804) - Starting to index...
# 2022-10-19 19:50:08,500 DEBUG [pool-2-thread-1] index.IndexCollection$LocalIndexerThread (IndexCollection.java:239) - iirc_indices/contents.jsonl: 146126 docs added.
# 2022-10-19 19:50:13,637 INFO  [main] index.IndexCollection (IndexCollection.java:888) - Indexing Complete! 146,126 documents indexed
# 2022-10-19 19:50:13,638 INFO  [main] index.IndexCollection (IndexCollection.java:889) - ============ Final Counter Values ============
# 2022-10-19 19:50:13,638 INFO  [main] index.IndexCollection (IndexCollection.java:890) - indexed:          146,126
# 2022-10-19 19:50:13,638 INFO  [main] index.IndexCollection (IndexCollection.java:891) - unindexable:            0
# 2022-10-19 19:50:13,638 INFO  [main] index.IndexCollection (IndexCollection.java:892) - empty:                  0
# 2022-10-19 19:50:13,639 INFO  [main] index.IndexCollection (IndexCollection.java:893) - skipped:                0
# 2022-10-19 19:50:13,639 INFO  [main] index.IndexCollection (IndexCollection.java:894) - errors:                 0
# 2022-10-19 19:50:13,645 INFO  [main] index.IndexCollection (IndexCollection.java:897) - Total 146,126 documents indexed in 00:00:21
